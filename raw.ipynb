# %%
spark.conf.set(
    "fs.azure.account.key.nehastrgacc.dfs.core.windows.net",
    ""
)

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
input_path = "abfss://raw@nehastrgacc.dfs.core.windows.net/DataSet"

sales_df = (
    spark.read
    .option("header",True)
    .option("inferSchema",True)
    .csv(input_path)
)

display(sales_df)
